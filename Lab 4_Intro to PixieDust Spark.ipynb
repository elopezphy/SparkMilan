# %% [markdown]
# # Hello PixieDust!
# This sample notebook provides you with an introduction to many features included in PixieDust. You can find more information about PixieDust at https://ibm-watson-data-lab.github.io/pixiedust/. To ensure you are running the latest version of PixieDust uncomment and run the following cell. Do not run this cell if you installed PixieDust locally from source and want to continue to run PixieDust from source.

# %%
# !pip install --user --upgrade pixiedust
# Out:
# Requirement already up-to-date: pixiedust in /usr/local/src/bluemix_jupyter_bundle.v82/notebook/lib/extra
# Requirement already up-to-date: mpld3 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from pixiedust)
# Requirement already up-to-date: lxml in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from pixiedust)
# Requirement already up-to-date: astunparse in /usr/local/src/bluemix_jupyter_bundle.v82/notebook/lib/python2.7/site-packages (from pixiedust)
# Requirement already up-to-date: geojson in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from pixiedust)
# Requirement already up-to-date: markdown in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from pixiedust)
# Requirement already up-to-date: six<2.0,>=1.6.1 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from astunparse->pixiedust)
# Requirement already up-to-date: wheel<1.0,>=0.23.0 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from astunparse->pixiedust)

# %% [markdown]
# # Import PixieDust
# Run the following cell to import the PixieDust library. You may need to restart your kernel after importing. Follow the instructions, if any, after running the cell. Note: You must import PixieDust every time you restart your kernel.

# %%
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.7.1</span>
#         </div>

# %% [markdown]
# # Enable the Spark Progress Monitor
# PixieDust includes a Spark Progress Monitor bar that lets you track the status of your Spark jobs. You can find more info at https://ibm-watson-data-lab.github.io/pixiedust/sparkmonitor.html. Note: there is a known issue with the Spark Progress Monitor on Spark 2.1. Run the following cell to enable the Spark Progress Monitor:

# %%
pixiedust.enableJobMonitor();
# Out:
# Spark Job Progress Monitoring cannot be started on DSX

# %% [markdown]
# # Example use of the PackageManager
# You can use the PackageManager component of Pixiedust to install and uninstall maven packages into your notebook kernel without editing configuration files. This component is essential when you run notebooks from a hosted cloud environment and do not have access to the configuration files. You can find more info at https://ibm-watson-data-lab.github.io/pixiedust/packagemanager.html. Run the following cell to install the GraphFrame package. You may need to restart your kernel after installing new packages. Follow the instructions, if any, after running the cell.

# %%
pixiedust.installPackage("graphframes:graphframes:0.1.0-spark1.6")
print("done")
# Out:
# Package already installed: graphframes:graphframes:0.1.0-spark1.6
# done

# %% [markdown]
# Run the following cell to print out all installed packages:

# %%
pixiedust.printAllPackages()
# Out:
# graphframes:graphframes:0.1.0-spark1.6 => /gpfs/fs01/user/s45f-395dc8c6c8c31d-f8f53e276d47/data/libs/graphframes-0.1.0-spark1.6.jar

# %%
# !pip install --user --upgrade bokeh
# Out:
# Requirement already up-to-date: bokeh in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages
# Requirement already up-to-date: tornado>=4.3 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: numpy>=1.7.1 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: six>=1.5.2 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: python-dateutil>=2.1 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: packaging>=16.8 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: PyYAML>=3.10 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: futures>=3.0.3 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: Jinja2>=2.7 in /usr/local/src/bluemix_jupyter_bundle.v82/notebook/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: certifi in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from tornado>=4.3->bokeh)
# Requirement already up-to-date: singledispatch in /usr/local/src/bluemix_jupyter_bundle.v82/notebook/lib/python2.7/site-packages (from tornado>=4.3->bokeh)
# Requirement already up-to-date: backports-abc>=0.4 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from tornado>=4.3->bokeh)
# Requirement already up-to-date: pyparsing>=2.0.2 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from packaging>=16.8->bokeh)
# Requirement already up-to-date: MarkupSafe>=0.23 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s45f-395dc8c6c8c31d-f8f53e276d47/.local/lib/python2.7/site-packages (from Jinja2>=2.7->bokeh)

# %% [markdown]
# # Example use of the display() API
# PixieDust lets you visualize your data in just a few clicks using the display() API. You can find more info at https://ibm-watson-data-lab.github.io/pixiedust/displayapi.html. The following cell creates a DataFrame and uses the display() API to create a bar chart:

# %%
sparkSession = SparkSession.builder.getOrCreate()
d1 = sparkSession.createDataFrame(
[(2010, 'Camping Equipment', 3),
 (2010, 'Golf Equipment', 1),
 (2010, 'Mountaineering Equipment', 1),
 (2010, 'Outdoor Protection', 2),
 (2010, 'Personal Accessories', 2),
 (2011, 'Camping Equipment', 4),
 (2011, 'Golf Equipment', 5),
 (2011, 'Mountaineering Equipment',2),
 (2011, 'Outdoor Protection', 4),
 (2011, 'Personal Accessories', 2),
 (2012, 'Camping Equipment', 5),
 (2012, 'Golf Equipment', 5),
 (2012, 'Mountaineering Equipment', 3),
 (2012, 'Outdoor Protection', 5),
 (2012, 'Personal Accessories', 3),
 (2013, 'Camping Equipment', 8),
 (2013, 'Golf Equipment', 5),
 (2013, 'Mountaineering Equipment', 3),
 (2013, 'Outdoor Protection', 8),
 (2013, 'Personal Accessories', 4)],
["year","zone","unique_customers"])

display(d1)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             Simple Chart
#         </div>
#     <div id="chartFigure00feaab0" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>

# %% [markdown]
# # Sample Data
# PixieDust includes a number of sample data sets. You can use these sample data sets to start playing with the display() API and other PixieDust features. You can find more info at https://ibm-watson-data-lab.github.io/pixiedust/loaddata.html. Run the following cell to view the available data sets:

# %%
pixiedust.sampleData()
# Out:
# <table class="table table-hover pd_save" style="font-size:small">
#   <thead>
#     <tr>
#       <th align="center" valign="middle">Id</th>
#       <th>Name</th>
#       <th>Topic</th>
#       <th>Publisher</th>
#     </tr>
#   </thead>
#   <tbody>
#
#
#     <tr>
#         <td>1</td>
#         <td>Car performance data</td>
#         <td>Transportation</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>2</td>
#         <td>Sample retail sales transactions, January 2009</td>
#         <td>Economy & Business</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>3</td>
#         <td>Total population by country</td>
#         <td>Society</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>4</td>
#         <td>GoSales Transactions for Naive Bayes Model</td>
#         <td>Leisure</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>5</td>
#         <td>Election results by County</td>
#         <td>Society</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>6</td>
#         <td>Million dollar home sales in NE Mass late 2016</td>
#         <td>Economy & Business</td>
#         <td>Redfin.com</td>
#     </tr>
#
#
#
#     <tr>
#         <td>7</td>
#         <td>Boston Crime data, 2-week sample</td>
#         <td>Society</td>
#         <td>City of Boston</td>
#     </tr>
#
#
#   </tbody>
# </table>

# %% [markdown]
# # Example use of sample data
# To use sample data locally run the following cell to install required packages. You may need to restart your kernel after running this cell.

# %%
pixiedust.installPackage("com.databricks:spark-csv_2.10:1.5.0")
pixiedust.installPackage("org.apache.commons:commons-csv:0")
# Out:
# Downloading package com.databricks:spark-csv_2.10:1.5.0 to /gpfs/fs01/user/s45f-395dc8c6c8c31d-f8f53e276d47/data/libs/spark-csv_2.10-1.5.0.jar
#                 <div>
#                     <span id="pm_label17733f31">Starting download...</span>
#                     <progress id="pm_progress17733f31" max="100" value="0" style="width:200px"></progress>
#                 </div>
# Package com.databricks:spark-csv_2.10:1.5.0 downloaded successfully
# Please restart Kernel to complete installation of the new package
# Successfully added package com.databricks:spark-csv_2.10:1.5.0
# Downloading package org.apache.commons:commons-csv:1.5 to /gpfs/fs01/user/s45f-395dc8c6c8c31d-f8f53e276d47/data/libs/commons-csv-1.5.jar
#                 <div>
#                     <span id="pm_label89f25b7a">Starting download...</span>
#                     <progress id="pm_progress89f25b7a" max="100" value="0" style="width:200px"></progress>
#                 </div>
# Package org.apache.commons:commons-csv:1.5 downloaded successfully
# Please restart Kernel to complete installation of the new package
# Successfully added package org.apache.commons:commons-csv:1.5

# %% [markdown]
# Run the following cell to get the first data set from the list. This will return a DataFrame and assign it to the variable d2:

# %%
d2 = pixiedust.sampleData(1)
# Out:
# Downloading 'Car performance data' from https://github.com/ibm-watson-data-lab/open-data/raw/master/cars/cars.csv
# Downloaded 20954 bytes
# Creating pySpark DataFrame for 'Car performance data'. Please wait...
# Loading file using 'SparkSession'
# Successfully created pySpark DataFrame for 'Car performance data'

# %% [markdown]
# Pass the sample data set (d2) into the display() API:

# %%
display(d2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure3e305a0e" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
#       background-color: #337ab7;
#       border-color: #2e6da4;
#       color: #ffffff;
#       display: block;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper {
#       font-size: small;
#       font-weight: 300;
#       letter-spacing: 0.5px;
#       line-height: normal;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-search {
#       margin: 0 0 20px 0;
#     }
#     .df-table-search-count {
#       display: inline-block;
#       margin: 0 0 20px 0;
#     }
#     .df-table-container {
#       max-height: 50vh;
#       max-width: 100%;
#       overflow-x: auto;
#       position: relative;
#     }
#     .df-table-wrapper table {
#       border: 0 none #ffffff;
#       border-collapse: collapse;
#       margin: 0;
#       min-width: 100%;
#       padding: 0;
#       table-layout: fixed;
#       height: inherit;
#       overflow: auto;
#     }
#     .df-table-wrapper tr.hidden {
#       display: none;
#     }
#     .df-table-wrapper tr:nth-child(even) {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.even {
#       background-color: #f9f9fb;
#     }
#     .df-table-wrapper tr.odd {
#       background-color: #ffffff;
#     }
#     .df-table-wrapper td + td {
#       border-left: 1px solid #e0e0e0;
#     }
#
#     .df-table-wrapper thead,
#     .fixed-header {
#       font-weight: 600;
#     }
#     .df-table-wrapper tr,
#     .fixed-row {
#       border: 0 none #ffffff;
#       margin: 0;
#       padding: 0;
#     }
#     .df-table-wrapper th,
#     .df-table-wrapper td,
#     .fixed-cell {
#       border: 0 none #ffffff;
#       margin: 0;
#       min-width: 50px;
#       padding: 5px 20px 5px 10px;
#       text-align: left;
#       word-wrap: break-word;
#     }
#     .df-table-wrapper th {
#       padding-bottom: 0;
#       padding-top: 0;
#     }
#     .df-table-wrapper th div {
#       max-height: 1px;
#       visibility: hidden;
#     }
#
#     .df-schema-field {
#       margin-left: 10px;
#     }
#
#     .fixed-header-container {
#       overflow: hidden;
#       position: relative;
#     }
#     .fixed-header {
#       border-bottom: 2px solid #000;
#       display: table;
#       position: relative;
#     }
#     .fixed-row {
#       display: table-row;
#     }
#     .fixed-cell {
#       display: table-cell;
#     }
#   </style>
#
#
#   <div class="df-table-wrapper df-table-wrapper-3e305a0e panel-group pd_save">
#     <!-- dataframe schema -->
#
#     <div class="panel panel-default">
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-schema-3e305a0e" data-parent="#df-table-wrapper-3e305a0e">Schema</a>
#         </h4>
#       </div>
#       <div id="df-schema-3e305a0e" class="panel-collapse collapse">
#         <div class="panel-body" style="font-family: monospace;">
#           <div class="df-schema-fields">
#             <div>Field types:</div>
#
#               <div class="df-schema-field"><strong>mpg: </strong> float64</div>
#
#               <div class="df-schema-field"><strong>cylinders: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>engine: </strong> float64</div>
#
#               <div class="df-schema-field"><strong>horsepower: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>weight: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>acceleration: </strong> float64</div>
#
#               <div class="df-schema-field"><strong>year: </strong> int64</div>
#
#               <div class="df-schema-field"><strong>origin: </strong> object</div>
#
#               <div class="df-schema-field"><strong>name: </strong> object</div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#
#     <!-- dataframe table -->
#     <div class="panel panel-default">
#
#       <div class="panel-heading">
#         <h4 class="panel-title" style="margin: 0px;">
#           <a data-toggle="collapse" href="#df-table-3e305a0e" data-parent="#df-table-wrapper-3e305a0e"> Table</a>
#         </h4>
#       </div>
#
#       <div id="df-table-3e305a0e" class="panel-collapse collapse in">
#         <div class="panel-body">
#
#           <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#
#           <div>
#
#             <span class="df-table-search-count">Showing 120 of 120 rows</span>
#
#           </div>
#           <!-- fixed header for when dataframe table scrolls -->
#           <div class="fixed-header-container">
#             <div class="fixed-header" style="width: 1351px;">
#               <div class="fixed-row">
#
#                 <div class="fixed-cell" style="width: 89px;">mpg</div>
#
#                 <div class="fixed-cell" style="width: 134px;">cylinders</div>
#
#                 <div class="fixed-cell" style="width: 110px;">engine</div>
#
#                 <div class="fixed-cell" style="width: 162px;">horsepower</div>
#
#                 <div class="fixed-cell" style="width: 110px;">weight</div>
#
#                 <div class="fixed-cell" style="width: 166px;">acceleration</div>
#
#                 <div class="fixed-cell" style="width: 89px;">year</div>
#
#                 <div class="fixed-cell" style="width: 140px;">origin</div>
#
#                 <div class="fixed-cell" style="width: 352px;">name</div>
#
#               </div>
#             </div>
#           </div>
#           <div class="df-table-container">
#             <table class="df-table">
#               <thead>
#                 <tr>
#
#                   <th><div>mpg</div></th>
#
#                   <th><div>cylinders</div></th>
#
#                   <th><div>engine</div></th>
#
#                   <th><div>horsepower</div></th>
#
#                   <th><div>weight</div></th>
#
#                   <th><div>acceleration</div></th>
#
#                   <th><div>year</div></th>
#
#                   <th><div>origin</div></th>
#
#                   <th><div>name</div></th>
#
#                 </tr>
#               </thead>
#               <tbody>
#
#                 <tr>
#
#                   <td>18.0</td>
#
#                   <td>8</td>
#
#                   <td>307.0</td>
#
#                   <td>130</td>
#
#                   <td>3504</td>
#
#                   <td>12.0</td>
#
#                   <td>70</td>
#
#                   <td>American</td>
#
#                   <td>chevrolet chevelle malibu</td>
#
#                 </tr>
#
#                 <tr>
#
#                   <td>15.0</td>
#
#                   <td>8</td>
#
#                   <td>350.0</td>

# %% [markdown]
# You can also download data from a CSV file into a DataFrame which you can use with the display() API:

# %%
d3 = pixiedust.sampleData("https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv")
# Out:
# Downloading 'https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv' from https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv
# Downloaded 102051 bytes
# Creating pySpark DataFrame for 'https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv'. Please wait...
# Loading file using 'SparkSession'
# Successfully created pySpark DataFrame for 'https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv'

# %% [markdown]
# # PixieDust Log

# %%
% pixiedustLog -l debug
# Out:
# 2018-03-02 17:57:27,565 - pixiedust.utils.storage - INFO - No change in version: 1.1.7.1 -> 1.1.7.1.
# 2018-03-02 17:57:53,421 - pixiedust.display - DEBUG - Creating a new display handler with options {}: <pixiedust.display.display.CellHandshakeMeta object at 0x7fabcf8f1e10>
# 2018-03-02 17:57:53,649 - pixiedust.display - DEBUG - Creating a new display handler with options {'clusterby': 'year', 'rendererId': 'bokeh', 'showchrome': 'true', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'nostore_cw': '1797', 'nostore_pixiedust': 'true', 'aggregation': 'SUM', 'org_params': 'nostore_pixiedust', 'rowCount': '100', 'valueFields': 'unique_customers', 'nostore_bokeh': 'false', 'showLegend': 'true', 'nostore_vh': '788', 'handlerId': 'barChart', 'charttype': 'grouped', 'stacked': 'false', 'keyFields': 'zone', 'title': 'Simple Bar Chart', 'staticFigure': 'false'}: <pixiedust.display.chart.ChartDisplayMeta object at 0x7fabe142eda0>
# 2018-03-02 17:57:53,657 - pixiedust.display.chart.renderers - DEBUG - Found renderer: bokeh - barChart
# 2018-03-02 17:57:53,803 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - Running with command: display(FilterApp_instance_161DC3D280284714BD876BAC7D9722A6,nostore_figureOnly='true',nostore_cw='1797',nostore_ispix='true',no_margin='true',cell_id='161DC3D280284714BD876BAC7D9722A6',runInDialog='false',nostore_isrunningchildpixieapp='true',handlerId='pixiedust.display.chart.filter.filter_FilterApp_id',nostore_pixieapp='FilterApp_instance_161DC3D280284714BD876BAC7D9722A6',targetDivId='ui-id-3') and var FilterApp_instance_161DC3D280284714BD876BAC7D9722A6
# 2018-03-02 17:57:53,804 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_figureOnly': 'true', 'runInDialog': 'false', 'nostore_cw': '1797', 'nostore_isrunningchildpixieapp': 'true', 'nostore_ispix': 'true', 'handlerId': 'pixiedust.display.chart.filter.filter_FilterApp_id', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'no_margin': 'true', 'nostore_pixieapp': 'FilterApp_instance_161DC3D280284714BD876BAC7D9722A6', 'targetDivId': 'ui-id-3'}: <abc.pixiedust.display.chart.filter.filter_FilterApp_Meta object at 0x7fabcf878400>
# 2018-03-02 17:57:53,934 - pixiedust.display - DEBUG - Creating a new display handler with options {'clusterby': 'year', 'rendererId': 'bokeh', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'nostore_pixiedust': 'true', 'aggregation': 'SUM', 'org_params': 'nostore_pixiedust', 'rowCount': '100', 'staticFigure': 'false', 'nostore_bokeh': 'false', 'showLegend': 'true', 'nostore_vh': '788', 'handlerId': 'barChart', 'charttype': 'grouped', 'keyFields': 'zone', 'stacked': 'false', 'nostore_cw': '1797', 'title': 'Simple Bar Chart', 'valueFields': 'unique_customers', 'prefix': '00feaab0'}: <pixiedust.display.chart.ChartDisplayMeta object at 0x7fabe142eda0>
# 2018-03-02 17:57:53,942 - pixiedust.display.chart.renderers - DEBUG - Found renderer: bokeh - barChart
# 2018-03-02 17:57:53,943 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - No Cache Entry found for 161DC3D280284714BD876BAC7D9722A6
# 2018-03-02 17:58:07,955 - pixiedust.display.display.Display - DEBUG - chartOptions [{'metadata': {'max': 100, 'min': 50, 'type': 'slider', 'default': 100}, 'name': 'chartsize', 'description': 'Chart Size'}, {'metadata': {'default': '', 'type': 'dropdown', 'values': ['None', 'year']}, 'name': 'clusterby', 'refresh': True, 'description': 'Cluster By', 'validate': <function clusterBy.<locals>.<lambda> at 0x7fabcf8739d8>}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'timeseries', 'description': 'Time Series'}, {'metadata': {'default': 'grouped', 'type': 'dropdown', 'values': ['grouped', 'stacked', 'subplots']}, 'name': 'charttype', 'description': 'Type'}, {'metadata': {'default': 'true', 'type': 'checkbox'}, 'name': 'legend', 'description': 'Show legend'}, {'metadata': {'default': 'Keys ASC', 'type': 'dropdown', 'values': ['Keys ASC', 'Keys DESC', 'Values ASC', 'Values DESC']}, 'name': 'sortby', 'description': 'Sort By'}]
# 2018-03-02 17:58:07,955 - pixiedust.display.display.Display - DEBUG - values: ['year']
# 2018-03-02 17:58:07,955 - pixiedust.display.display.Display - DEBUG - Calling validation for option clusterby with value year
# 2018-03-02 17:58:07,956 - pixiedust.utils.template - DEBUG - Template already qualified pixiedust.display.chart.renderers.baseChartDisplay:baseChartOptionsDialogBody.html
# 2018-03-02 17:58:26,488 - pixiedust.display - DEBUG - Creating a new display handler with options {'clusterby': 'year', 'rendererId': 'bokeh', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'nostore_pixiedust': 'true', 'aggregation': 'SUM', 'org_params': 'nostore_pixiedust', 'rowCount': '100', 'staticFigure': 'false', 'nostore_bokeh': 'false', 'showLegend': 'true', 'nostore_vh': '788', 'handlerId': 'lineChart', 'charttype': 'grouped', 'keyFields': 'zone', 'stacked': 'false', 'nostore_cw': '1797', 'title': 'Simple Bar Chart', 'valueFields': 'unique_customers', 'prefix': '00feaab0'}: <pixiedust.display.chart.ChartDisplayMeta object at 0x7fabe142eda0>
# 2018-03-02 17:58:26,500 - pixiedust.display.chart.renderers - DEBUG - Found renderer: bokeh - lineChart
# 2018-03-02 17:58:26,500 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - Found cache data for 161DC3D280284714BD876BAC7D9722A6. Validating integrity...
# 2018-03-02 17:58:26,500 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - Cache data validated for 161DC3D280284714BD876BAC7D9722A6. Using it!...
# 2018-03-02 17:58:26,500 - pixiedust.display.display.Display - DEBUG - chartOptions [{'metadata': {'max': 100, 'min': 50, 'type': 'slider', 'default': 100}, 'name': 'chartsize', 'description': 'Chart Size'}, {'metadata': {'default': '', 'type': 'dropdown', 'values': ['None', 'year']}, 'name': 'clusterby', 'refresh': True, 'description': 'Cluster By', 'validate': <function clusterBy.<locals>.<lambda> at 0x7fabcf819378>}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'timeseries', 'description': 'Time Series'}, {'metadata': {'default': 'grouped', 'type': 'dropdown', 'values': ['grouped', 'subplots']}, 'name': 'lineChartType', 'description': 'Type'}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'legend', 'description': 'Show legend'}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'logx', 'description': 'log scale on x'}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'logy', 'description': 'log scale on y'}]
# 2018-03-02 17:58:26,500 - pixiedust.display.display.Display - DEBUG - values: ['year']
# 2018-03-02 17:58:26,501 - pixiedust.display.display.Display - DEBUG - Calling validation for option clusterby with value year
# 2018-03-02 17:58:26,501 - pixiedust.utils.template - DEBUG - Template already qualified pixiedust.display.chart.renderers.baseChartDisplay:baseChartOptionsDialogBody.html
# 2018-03-02 17:58:42,363 - pixiedust.display - DEBUG - Creating a new display handler with options {'clusterby': 'year', 'rendererId': 'bokeh', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'nostore_pixiedust': 'true', 'aggregation': 'SUM', 'org_params': 'nostore_pixiedust', 'rowCount': '100', 'staticFigure': 'false', 'nostore_bokeh': 'false', 'showLegend': 'true', 'nostore_vh': '788', 'handlerId': 'pieChart', 'charttype': 'grouped', 'keyFields': 'zone', 'stacked': 'false', 'nostore_cw': '1797', 'title': 'Simple Bar Chart', 'valueFields': 'unique_customers', 'prefix': '00feaab0'}: <pixiedust.display.chart.ChartDisplayMeta object at 0x7fabe142eda0>
# 2018-03-02 17:58:42,375 - pixiedust.display.chart.renderers - DEBUG - Defaulting to first renderer matplotlib - pieChart
# 2018-03-02 17:58:42,376 - pixiedust.display.display.Display - DEBUG - chartOptions [{'metadata': {'max': 100, 'min': 50, 'type': 'slider', 'default': 100}, 'name': 'chartsize', 'description': 'Chart Size'}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'mpld3', 'refresh': True, 'description': 'D3 Rendering (mpld3)'}, {'metadata': {'default': 'true', 'type': 'checkbox'}, 'name': 'legend', 'description': 'Show legend'}]
# 2018-03-02 17:58:42,376 - pixiedust.utils.template - DEBUG - Template already qualified pixiedust.display.chart.renderers.baseChartDisplay:baseChartOptionsDialogBody.html
# 2018-03-02 17:58:42,467 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - Found cache data for 161DC3D280284714BD876BAC7D9722A6. Validating integrity...
# 2018-03-02 17:58:42,467 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - Cache data not validated for key extraFields. Expected Value is ['year']. Got []. Destroying it!...
# 2018-03-02 17:59:04,349 - pixiedust.display.chart.renderers - DEBUG - Defaulting to first renderer matplotlib - pieChart
# 2018-03-02 17:59:04,349 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - Running with command: display(DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6,nostore_figureOnly='true',cell_id='161DC3D280284714BD876BAC7D9722A6',nostore_ispix='true',nostore_cw='1797',runInDialog='true',nostore_isrunningchildpixieapp='true',handlerId='pixiedust.display.chart.options.defaultOptions_DefaultOptions_id',title='Pie Chart Options',customClass='pixiedust-default-dialog',nostore_pixieapp='DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6',targetDivId='option_btn_00feaab0',showFooter='true') and var DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6
# 2018-03-02 17:59:04,350 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_figureOnly': 'true', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'nostore_ispix': 'true', 'runInDialog': 'true', 'handlerId': 'pixiedust.display.chart.options.defaultOptions_DefaultOptions_id', 'nostore_isrunningchildpixieapp': 'true', 'nostore_cw': '1797', 'title': 'Pie Chart Options', 'customClass': 'pixiedust-default-dialog', 'nostore_pixieapp': 'DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6', 'targetDivId': 'option_btn_00feaab0', 'showFooter': 'true'}: <pixiedust.display.display.RunInDialogMeta object at 0x7fabcf85f828>
# 2018-03-02 17:59:04,445 - pixiedust.display.display.Display - DEBUG - In RunInDialog
# 2018-03-02 17:59:05,046 - pixiedust.display - DEBUG - Creating a new display handler with options {'clusterby': 'year', 'nostore_figureOnly': 'true', 'nostore_cw': '1797', 'nostore_isrunningchildpixieapp': 'true', 'rendererId': 'bokeh', 'aggregation': 'SUM', 'rowCount': '100', 'showLegend': 'true', 'nostore_ispix': 'true', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'customClass': 'pixiedust-default-dialog', 'nostore_pixieapp': 'DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6', 'valueFields': 'unique_customers', 'showFooter': 'true', 'nostore_pixiedust': 'true', 'charttype': 'grouped', 'staticFigure': 'false', 'handlerId': 'pixiedust.display.chart.options.defaultOptions_DefaultOptions_id', 'stacked': 'false', 'keyFields': 'zone', 'title': 'Simple Bar Chart', 'targetDivId': 'dialog10a6e0ecroot'}: <abc.pixiedust.display.chart.options.defaultOptions_DefaultOptions_Meta object at 0x7fabcf880828>
# 2018-03-02 17:59:05,176 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_figureOnly': 'true', 'nostore_cw': '863', 'nostore_ispix': 'true', 'nostore_pixiedust': 'true', 'no_margin': 'true', 'prefix': '10a6e0ec', 'nostore_bokeh': 'true', 'handlerId': 'pixiedust.display.chart.options.defaultOptions_DefaultOptions_id', 'optid': 'title', 'nostore_isrunningchildpixieapp': 'true', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'title': 'Simple Bar Chart', 'customClass': 'pixiedust-default-dialog', 'nostore_pixieapp': 'DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6', 'targetDivId': 'ui-id-4', 'widget': 'pdChartOptionTitle', 'showFooter': 'true'}: <abc.pixiedust.display.chart.options.defaultOptions_DefaultOptions_Meta object at 0x7fabcf880828>
# 2018-03-02 17:59:05,176 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - match found: {'widget': 'pdChartOptionTitle'}
# 2018-03-02 17:59:05,176 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - Injected args: OrderedDict([('optid', 'title'), ('title', 'Simple Bar Chart')])
# 2018-03-02 17:59:05,190 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_figureOnly': 'true', 'classname': 'no_loading_msg', 'nostore_cw': '863', 'nostore_ispix': 'true', 'nostore_pixiedust': 'true', 'no_margin': 'true', 'prefix': '10a6e0ec', 'valueFields': 'unique_customers', 'nostore_bokeh': 'true', 'handlerId': 'pixiedust.display.chart.options.defaultOptions_DefaultOptions_id', 'optid': 'keyvalue', 'nostore_isrunningchildpixieapp': 'true', 'keyFields': 'zone', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'title': 'Pie Chart Options', 'customClass': 'pixiedust-default-dialog', 'nostore_pixieapp': 'DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6', 'targetDivId': 'ui-id-5', 'widget': 'pdKeyValueSelector', 'showFooter': 'true'}: <abc.pixiedust.display.chart.options.defaultOptions_DefaultOptions_Meta object at 0x7fabcf880828>
# 2018-03-02 17:59:05,190 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - match found: {'widget': 'pdKeyValueSelector'}
# 2018-03-02 17:59:05,190 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - Injected args: OrderedDict([('optid', 'keyvalue'), ('keyFields', 'zone'), ('valueFields', 'unique_customers')])
# 2018-03-02 17:59:05,202 - pixiedust.display.chart.renderers - DEBUG - Defaulting to first renderer matplotlib - pieChart
# 2018-03-02 17:59:05,247 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_figureOnly': 'true', 'classname': 'field-width-50 no_loading_msg', 'nostore_cw': '427', 'nostore_ispix': 'true', 'nostore_pixiedust': 'true', 'no_margin': 'true', 'aggregation': 'SUM', 'nostore_bokeh': 'true', 'handlerId': 'pixiedust.display.chart.options.defaultOptions_DefaultOptions_id', 'optid': 'aggregation', 'nostore_isrunningchildpixieapp': 'true', 'prefix': '10a6e0ec', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'title': 'Pie Chart Options', 'customClass': 'pixiedust-default-dialog', 'nostore_pixieapp': 'DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6', 'targetDivId': 'ui-id-6', 'widget': 'pdAggregationSelector', 'showFooter': 'true'}: <abc.pixiedust.display.chart.options.defaultOptions_DefaultOptions_Meta object at 0x7fabcf880828>
# 2018-03-02 17:59:05,247 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - match found: {'widget': 'pdAggregationSelector'}
# 2018-03-02 17:59:05,247 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - Injected args: OrderedDict([('optid', 'aggregation'), ('aggregation', 'SUM')])
# 2018-03-02 17:59:05,262 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_figureOnly': 'true', 'classname': 'field-width-50 no_loading_msg', 'nostore_cw': '422', 'nostore_ispix': 'true', 'nostore_pixiedust': 'true', 'no_margin': 'true', 'prefix': '10a6e0ec', 'nostore_bokeh': 'true', 'count': '100', 'handlerId': 'pixiedust.display.chart.options.defaultOptions_DefaultOptions_id', 'optid': 'rowCount', 'nostore_isrunningchildpixieapp': 'true', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'title': 'Pie Chart Options', 'customClass': 'pixiedust-default-dialog', 'nostore_pixieapp': 'DefaultOptions_instance_161DC3D280284714BD876BAC7D9722A6', 'targetDivId': 'ui-id-7', 'widget': 'pdRowCount', 'showFooter': 'true'}: <abc.pixiedust.display.chart.options.defaultOptions_DefaultOptions_Meta object at 0x7fabcf880828>
# 2018-03-02 17:59:05,263 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - match found: {'widget': 'pdRowCount'}
# 2018-03-02 17:59:05,263 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - Injected args: OrderedDict([('optid', 'rowCount'), ('count', '100')])
# 2018-03-02 17:59:17,302 - pixiedust.display - DEBUG - Creating a new display handler with options {'clusterby': 'year', 'rendererId': 'bokeh', 'aggregation': 'SUM', 'cell_id': '161DC3D280284714BD876BAC7D9722A6', 'prefix': '00feaab0', 'nostore_pixiedust': 'true', 'org_params': 'nostore_pixiedust', 'rowCount': '100', 'valueFields': 'unique_customers', 'nostore_bokeh': 'true', 'showLegend': 'true', 'nostore_vh': '788', 'handlerId': 'pieChart', 'charttype': 'grouped', 'stacked': 'false', 'keyFields': 'zone', 'title': 'Simple Chart', 'staticFigure': 'false'}: <pixiedust.display.chart.ChartDisplayMeta object at 0x7fabe142eda0>
# 2018-03-02 17:59:17,311 - pixiedust.display.chart.renderers - DEBUG - Defaulting to first renderer matplotlib - pieChart
# 2018-03-02 17:59:17,312 - pixiedust.display.display.Display - DEBUG - chartOptions [{'metadata': {'max': 100, 'min': 50, 'type': 'slider', 'default': 100}, 'name': 'chartsize', 'description': 'Chart Size'}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'mpld3', 'refresh': True, 'description': 'D3 Rendering (mpld3)'}, {'metadata': {'default': 'true', 'type': 'checkbox'}, 'name': 'legend', 'description': 'Show legend'}]
# 2018-03-02 17:59:17,312 - pixiedust.utils.template - DEBUG - Template already qualified pixiedust.display.chart.renderers.baseChartDisplay:baseChartOptionsDialogBody.html
# 2018-03-02 17:59:17,363 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - Found cache data for 161DC3D280284714BD876BAC7D9722A6. Validating integrity...
# 2018-03-02 17:59:17,363 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - Cache data validated for 161DC3D280284714BD876BAC7D9722A6. Using it!...
# 2018-03-02 17:59:31,668 - pixiedust.utils.scalaBridge.PixiedustScalaMagics - DEBUG - Calling scala compiler with command: /usr/local/src/scala/2.11/bin/scalac -classpath /gpfs/fs01/user/s45f-395dc8c6c8c31d-f8f53e276d47/notebook/spark-config/spark20master-python3/:/usr/local/src/spark20master/spark/ego/spark-launcher_2.11-2.0.2.jar:/usr/local/src/spark20master/spark/ego/spark-network-shuffle_2.11-2.0.2.jar:/usr/local/src/spark20master/spark/ego/gson-2.2.4.jar:/usr/local/src/spark20master/spark/ego/guava-14.0.1.jar:/usr/local/src/spark20master/spark/ego/Java-WebSocket-1.3.0.jar:/usr/local/src/spark20master/spark/ego/spark-ego_2.11-2.0.2.jar:/gpfs/fs01/user/s45f-395dc8c6c8c31d-f8f53e276d47/notebook/spark-config/spark20master-python3/:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/JavaEWAH-0.3.2.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/RoaringBitmap-0.5.11.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/ST4-4.0.4.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/activation-1.1.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/antlr-2.7.7.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/antlr-runtime-3.4.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/antlr4-runtime-4.5.3.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/aopalliance-repackaged-2.4.0-b34.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/apache-log4j-extras-1.2.17.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/apacheds-i18n-2.0.0-M15.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/apacheds-kerberos-codec-2.0.0-M15.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/api-asn1-api-1.0.0-M20.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/api-util-1.0.0-M20.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/arpack_combined_all-0.1.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/avro-1.7.7.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/avro-ipc-1.7.7.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/avro-mapred-1.7.7-hadoop2.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/bonecp-0.8.0.RELEASE.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/breeze-macros_2.11-0.11.2.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/breeze_2.11-0.11.2.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/calcite-avatica-1.2.0-incubating.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/calcite-core-1.2.0-incubating.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/calcite-linq4j-1.2.0-incubating.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/chill-java-0.8.0.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/chill_2.11-0.8.0.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-beanutils-1.7.0.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-beanutils-core-1.8.0.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-cli-1.2.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-codec-1.10.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-collections-3.2.2.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-compiler-2.7.6.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-compress-1.4.1.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-configuration-1.6.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-dbcp-1.4.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-digester-1.8.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-httpclient-3.1.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-io-2.4.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-lang-2.6.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-lang3-3.3.2.jar:/usr/local/src/spark20master/spark-2.0.2-bin-2.7.3/jars/commons-logging-1.1.3 ...
# 2018-03-02 18:01:11,963 - pixiedust.display - DEBUG - Creating a new display handler with options {}: <pixiedust.display.display.CellHandshakeMeta object at 0x7fabf41108d0>
# 2018-03-02 18:01:12,206 - pixiedust.display.display - DEBUG - Unable to resolve handlerId dataframe for entity DataFrame[mpg: double, cylinders: int, engine: double, horsepower: int, weight: int, acceleration: double, year: int, origin: string, name: string]. Trying to find a suitable one
# 2018-03-02 18:01:12,206 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_bokeh': 'true', 'showchrome': 'true', 'nostore_vh': '788', 'handlerId': 'tableView', 'nostore_cw': '1797', 'nostore_pixiedust': 'true', 'cell_id': '82EA3631672D497EBDB04DC096B64752', 'org_params': 'nostore_pixiedust'}: <pixiedust.display.chart.ChartDisplayMeta object at 0x7fabe142eda0>
# 2018-03-02 18:01:12,206 - pixiedust.display.chart.renderers - DEBUG - Defaulting to first renderer table - tableView
# 2018-03-02 18:01:12,342 - pixiedust.display.chart.options.baseOptions.BaseOptions - DEBUG - Running with command: display(FilterApp_instance_82EA3631672D497EBDB04DC096B64752,nostore_figureOnly='true',nostore_cw='1797',nostore_ispix='true',no_margin='true',cell_id='82EA3631672D497EBDB04DC096B64752',runInDialog='false',nostore_isrunningchildpixieapp='true',handlerId='pixiedust.display.chart.filter.filter_FilterApp_id',nostore_pixieapp='FilterApp_instance_82EA3631672D497EBDB04DC096B64752',targetDivId='ui-id-8') and var FilterApp_instance_82EA3631672D497EBDB04DC096B64752
# 2018-03-02 18:01:12,342 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_figureOnly': 'true', 'runInDialog': 'false', 'nostore_cw': '1797', 'nostore_isrunningchildpixieapp': 'true', 'nostore_ispix': 'true', 'handlerId': 'pixiedust.display.chart.filter.filter_FilterApp_id', 'cell_id': '82EA3631672D497EBDB04DC096B64752', 'no_margin': 'true', 'nostore_pixieapp': 'FilterApp_instance_82EA3631672D497EBDB04DC096B64752', 'targetDivId': 'ui-id-8'}: <abc.pixiedust.display.chart.filter.filter_FilterApp_Meta object at 0x7fabcf878400>
# 2018-03-02 18:01:12,458 - pixiedust.display - DEBUG - Creating a new display handler with options {'nostore_bokeh': 'true', 'cell_id': '82EA3631672D497EBDB04DC096B64752', 'nostore_vh': '788', 'nostore_cw': '1797', 'nostore_pixiedust': 'true', 'handlerId': 'tableView', 'org_params': 'nostore_pixiedust', 'prefix': '3e305a0e'}: <pixiedust.display.chart.ChartDisplayMeta object at 0x7fabe142eda0>
# 2018-03-02 18:01:12,458 - pixiedust.display.chart.renderers - DEBUG - Defaulting to first renderer table - tableView
# 2018-03-02 18:01:12,459 - pixiedust.display.display.Display - DEBUG - chartOptions [{'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'table_noschema', 'description': 'Hide Schema'}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'table_nosearch', 'description': 'Hide Search'}, {'metadata': {'default': 'false', 'type': 'checkbox'}, 'name': 'table_nocount', 'description': 'Hide Row Count'}]
# 2018-03-02 18:01:12,459 - pixiedust.utils.template - DEBUG - Template already qualified pixiedust.display.chart.renderers.baseChartDisplay:baseChartOptionsDialogBody.html
# 2018-03-02 18:01:12,479 - pixiedust.display.chart.renderers.baseChartDisplay - DEBUG - No Cache Entry found for 82EA3631672D497EBDB04DC096B64752

# %% [markdown]
# # More Info.
# For more information about PixieDust check out the following:
# #### PixieDust Documentation: https://ibm-watson-data-lab.github.io/pixiedust/index.html
# #### PixieDust GitHub Repo: https://github.com/ibm-watson-data-lab/pixiedust
